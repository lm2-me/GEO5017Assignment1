# %%
import numpy as np
import matplotlib.pyplot as plt
import os


#pointcloudsdummy = np.random.randn(800).reshape((100,8))

#pointcloudsdummy = np.random.randint(0,500,3000).reshape((500,6))

cwd = os.getcwd()

print(cwd)

# np.savetxt('features_norm.csv', normalized_object_features, delimiter=',')
dataload = np.loadtxt('features_norm.csv', delimiter=',')

features_only = dataload[:,1:]

print(features_only)

# D = np.transpose(features_only)
D = features_only

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D, widths=1,
                   showmeans=False, showmedians=False, showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.9)
ax.set(xlim=(0, 7), xticks=np.arange(1, 7),
       ylim=(0, 1), yticks=np.arange(1, 1))

# height = objectHeight(currentPointCloud)
#         volume = convexHull(currentPointCloud_o3d)
#         avg_height = objectAverageHeight(currentPointCloud)
#         area, ratio = areaBase(currentPointCloud_o3d)
#         num_planes = planarityPC(currentPointCloud_o3d)

plt.xticks(ticks=[1,2,3,4,5,6],labels=['height','volume','avg_height','area','ratio','num_planes'])

plt.show()
# Out:
# c:\Users\sebas\Documents\GitHub\GEO5017Assignment1
# [[5.10467948e-01 1.22456579e-02 7.16721088e-01 1.19357661e-02
#   7.58748567e-02 5.71428571e-02]
#  [1.63793104e-01 6.40103615e-03 2.29410802e-01 1.59465520e-02
#   5.75266014e-02 8.57142857e-02]
#  [3.82389139e-01 1.29093539e-01 4.86471847e-01 6.83780158e-02
#   3.51322893e-02 1.14285714e-01]
#  ...
#  [2.45073871e-01 2.37211983e-02 2.32108161e-01 8.87583204e-03
#   2.49524291e-02 3.14285714e-01]
#  [4.85221653e-01 1.92382025e-02 4.85373197e-01 9.82679037e-03
#   1.30584813e-02 3.71428571e-01]
#  [2.69396529e-01 6.69211837e-04 3.11312808e-01 1.07904047e-02
#   2.53565191e-02 3.71428571e-01]]
